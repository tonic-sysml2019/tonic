# %%
from __future__ import print_function
import os
import numpy as np
import keras

import keras.backend as K
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from keras.optimizers import SGD, Adam, RMSprop
from keras.callbacks import LearningRateScheduler
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

np.random.seed(1337)

# %%
batch_size = 128
nb_epoch = 100
nb_classes = 10

# %%
# dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, nb_classes)
y_test = keras.utils.to_categorical(y_test, nb_classes)

# %%
# simple MLP
model = Sequential()
model.add(Dense(4096, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 4096)              3215360
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 20,037,642
# Trainable params: 20,037,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
path = 'saved_models'

save_dir = os.path.join(os.getcwd(), path)
model_name = 'MLP_mnist_model.{epoch:03d}-{val_acc:.2f}.h5'
filepath = os.path.join(save_dir, model_name)
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)  

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=nb_epoch,
                    callbacks=[checkpoint],
                    verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 13s 219us/step - loss: 0.2967 - acc: 0.9249 - val_loss: 0.1322 - val_acc: 0.9600
#
# Epoch 00001: val_acc improved from -inf to 0.96000, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.001-0.96.h5
# Epoch 2/100
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.1243 - acc: 0.9666 - val_loss: 0.0958 - val_acc: 0.9768
#
# Epoch 00002: val_acc improved from 0.96000 to 0.97680, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.002-0.98.h5
# Epoch 3/100
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.0994 - acc: 0.9754 - val_loss: 0.1312 - val_acc: 0.9683
#
# Epoch 00003: val_acc did not improve from 0.97680
# Epoch 4/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0868 - acc: 0.9796 - val_loss: 0.1198 - val_acc: 0.9788
#
# Epoch 00004: val_acc improved from 0.97680 to 0.97880, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.004-0.98.h5
# Epoch 5/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0776 - acc: 0.9829 - val_loss: 0.1033 - val_acc: 0.9813
#
# Epoch 00005: val_acc improved from 0.97880 to 0.98130, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.005-0.98.h5
# Epoch 6/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0738 - acc: 0.9842 - val_loss: 0.1466 - val_acc: 0.9774
#
# Epoch 00006: val_acc did not improve from 0.98130
# Epoch 7/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0675 - acc: 0.9856 - val_loss: 0.1376 - val_acc: 0.9776
#
# Epoch 00007: val_acc did not improve from 0.98130
# Epoch 8/100
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.0630 - acc: 0.9880 - val_loss: 0.1309 - val_acc: 0.9805
#
# Epoch 00008: val_acc did not improve from 0.98130
# Epoch 9/100
# 60000/60000 [==============================] - 10s 173us/step - loss: 0.0615 - acc: 0.9887 - val_loss: 0.1365 - val_acc: 0.9798
#
# Epoch 00009: val_acc did not improve from 0.98130
# Epoch 10/100
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0602 - acc: 0.9890 - val_loss: 0.1198 - val_acc: 0.9824
#
# Epoch 00010: val_acc improved from 0.98130 to 0.98240, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.010-0.98.h5
# Epoch 11/100
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0553 - acc: 0.9902 - val_loss: 0.1708 - val_acc: 0.9795
#
# Epoch 00011: val_acc did not improve from 0.98240
# Epoch 12/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 0.0635 - acc: 0.9898 - val_loss: 0.1872 - val_acc: 0.9761
#
# Epoch 00012: val_acc did not improve from 0.98240
# Epoch 13/100
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0577 - acc: 0.9909 - val_loss: 0.1670 - val_acc: 0.9807
#
# Epoch 00013: val_acc did not improve from 0.98240
# Epoch 14/100
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0558 - acc: 0.9918 - val_loss: 0.1753 - val_acc: 0.9804
#
# Epoch 00014: val_acc did not improve from 0.98240
# Epoch 15/100
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0531 - acc: 0.9923 - val_loss: 0.1681 - val_acc: 0.9823
#
# Epoch 00015: val_acc did not improve from 0.98240
# Epoch 16/100
# 60000/60000 [==============================] - 10s 175us/step - loss: 0.0515 - acc: 0.9926 - val_loss: 0.1840 - val_acc: 0.9822
#
# Epoch 00016: val_acc did not improve from 0.98240
# Epoch 17/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0556 - acc: 0.9926 - val_loss: 0.1961 - val_acc: 0.9792
#
# Epoch 00017: val_acc did not improve from 0.98240
# Epoch 18/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0569 - acc: 0.9929 - val_loss: 0.1915 - val_acc: 0.9806
#
# Epoch 00018: val_acc did not improve from 0.98240
# Epoch 19/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0538 - acc: 0.9933 - val_loss: 0.1743 - val_acc: 0.9825
#
# Epoch 00019: val_acc improved from 0.98240 to 0.98250, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.019-0.98.h5
# Epoch 20/100
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0491 - acc: 0.9937 - val_loss: 0.1852 - val_acc: 0.9821
#
# Epoch 00020: val_acc did not improve from 0.98250
# Epoch 21/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0475 - acc: 0.9941 - val_loss: 0.2033 - val_acc: 0.9802
#
# Epoch 00021: val_acc did not improve from 0.98250
# Epoch 22/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0509 - acc: 0.9938 - val_loss: 0.1942 - val_acc: 0.9801
#
# Epoch 00022: val_acc did not improve from 0.98250
# Epoch 23/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0446 - acc: 0.9941 - val_loss: 0.1919 - val_acc: 0.9818
#
# Epoch 00023: val_acc did not improve from 0.98250
# Epoch 24/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0435 - acc: 0.9948 - val_loss: 0.2113 - val_acc: 0.9809
#
# Epoch 00024: val_acc did not improve from 0.98250
# Epoch 25/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0398 - acc: 0.9951 - val_loss: 0.1909 - val_acc: 0.9829
#
# Epoch 00025: val_acc improved from 0.98250 to 0.98290, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.025-0.98.h5
# Epoch 26/100
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0459 - acc: 0.9949 - val_loss: 0.1856 - val_acc: 0.9837
#
# Epoch 00026: val_acc improved from 0.98290 to 0.98370, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.026-0.98.h5
# Epoch 27/100
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0443 - acc: 0.9948 - val_loss: 0.2196 - val_acc: 0.9820
#
# Epoch 00027: val_acc did not improve from 0.98370
# Epoch 28/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0407 - acc: 0.9952 - val_loss: 0.1917 - val_acc: 0.9825
#
# Epoch 00028: val_acc did not improve from 0.98370
# Epoch 29/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0390 - acc: 0.9955 - val_loss: 0.2174 - val_acc: 0.9816
#
# Epoch 00029: val_acc did not improve from 0.98370
# Epoch 30/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0458 - acc: 0.9952 - val_loss: 0.1985 - val_acc: 0.9832
#
# Epoch 00030: val_acc did not improve from 0.98370
# Epoch 31/100
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.0484 - acc: 0.9950 - val_loss: 0.1892 - val_acc: 0.9838
#
# Epoch 00031: val_acc improved from 0.98370 to 0.98380, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.031-0.98.h5
# Epoch 32/100
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0433 - acc: 0.9954 - val_loss: 0.2447 - val_acc: 0.9793
#
# Epoch 00032: val_acc did not improve from 0.98380
# Epoch 33/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0546 - acc: 0.9949 - val_loss: 0.1770 - val_acc: 0.9848
#
# Epoch 00033: val_acc improved from 0.98380 to 0.98480, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.033-0.98.h5
# Epoch 34/100
# 60000/60000 [==============================] - 11s 175us/step - loss: 0.0395 - acc: 0.9960 - val_loss: 0.1978 - val_acc: 0.9842
#
# Epoch 00034: val_acc did not improve from 0.98480
# Epoch 35/100
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0459 - acc: 0.9954 - val_loss: 0.2190 - val_acc: 0.9823
#
# Epoch 00035: val_acc did not improve from 0.98480
# Epoch 36/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0551 - acc: 0.9949 - val_loss: 0.2467 - val_acc: 0.9814
#
# Epoch 00036: val_acc did not improve from 0.98480
# Epoch 37/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0385 - acc: 0.9961 - val_loss: 0.2122 - val_acc: 0.9826
#
# Epoch 00037: val_acc did not improve from 0.98480
# Epoch 38/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0353 - acc: 0.9962 - val_loss: 0.2198 - val_acc: 0.9830
#
# Epoch 00038: val_acc did not improve from 0.98480
# Epoch 39/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0347 - acc: 0.9967 - val_loss: 0.2310 - val_acc: 0.9811
#
# Epoch 00039: val_acc did not improve from 0.98480
# Epoch 40/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0477 - acc: 0.9953 - val_loss: 0.2301 - val_acc: 0.9825
#
# Epoch 00040: val_acc did not improve from 0.98480
# Epoch 41/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0371 - acc: 0.9963 - val_loss: 0.2126 - val_acc: 0.9831
#
# Epoch 00041: val_acc did not improve from 0.98480
# Epoch 42/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0411 - acc: 0.9962 - val_loss: 0.2008 - val_acc: 0.9839
#
# Epoch 00042: val_acc did not improve from 0.98480
# Epoch 43/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0370 - acc: 0.9964 - val_loss: 0.2011 - val_acc: 0.9838
#
# Epoch 00043: val_acc did not improve from 0.98480
# Epoch 44/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0351 - acc: 0.9964 - val_loss: 0.2066 - val_acc: 0.9837
#
# Epoch 00044: val_acc did not improve from 0.98480
# Epoch 45/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0391 - acc: 0.9963 - val_loss: 0.2342 - val_acc: 0.9824
#
# Epoch 00045: val_acc did not improve from 0.98480
# Epoch 46/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0379 - acc: 0.9964 - val_loss: 0.2259 - val_acc: 0.9821
#
# Epoch 00046: val_acc did not improve from 0.98480
# Epoch 47/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0358 - acc: 0.9966 - val_loss: 0.2272 - val_acc: 0.9829
#
# Epoch 00047: val_acc did not improve from 0.98480
# Epoch 48/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0362 - acc: 0.9965 - val_loss: 0.1862 - val_acc: 0.9850
#
# Epoch 00048: val_acc improved from 0.98480 to 0.98500, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.048-0.98.h5
# Epoch 49/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0374 - acc: 0.9966 - val_loss: 0.2324 - val_acc: 0.9822
#
# Epoch 00049: val_acc did not improve from 0.98500
# Epoch 50/100
# 60000/60000 [==============================] - 11s 181us/step - loss: 0.0318 - acc: 0.9969 - val_loss: 0.2182 - val_acc: 0.9823
#
# Epoch 00050: val_acc did not improve from 0.98500
# Epoch 51/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0301 - acc: 0.9972 - val_loss: 0.2297 - val_acc: 0.9823
#
# Epoch 00051: val_acc did not improve from 0.98500
# Epoch 52/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0275 - acc: 0.9975 - val_loss: 0.1722 - val_acc: 0.9863
#
# Epoch 00052: val_acc improved from 0.98500 to 0.98630, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.052-0.99.h5
# Epoch 53/100
# 60000/60000 [==============================] - 11s 177us/step - loss: 0.0330 - acc: 0.9970 - val_loss: 0.2231 - val_acc: 0.9819
#
# Epoch 00053: val_acc did not improve from 0.98630
# Epoch 54/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0392 - acc: 0.9966 - val_loss: 0.2309 - val_acc: 0.9823
#
# Epoch 00054: val_acc did not improve from 0.98630
# Epoch 55/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0376 - acc: 0.9966 - val_loss: 0.2316 - val_acc: 0.9830
#
# Epoch 00055: val_acc did not improve from 0.98630
# Epoch 56/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0356 - acc: 0.9969 - val_loss: 0.1999 - val_acc: 0.9845
#
# Epoch 00056: val_acc did not improve from 0.98630
# Epoch 57/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0371 - acc: 0.9966 - val_loss: 0.2057 - val_acc: 0.9843
#
# Epoch 00057: val_acc did not improve from 0.98630
# Epoch 58/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0366 - acc: 0.9968 - val_loss: 0.2174 - val_acc: 0.9841
#
# Epoch 00058: val_acc did not improve from 0.98630
# Epoch 59/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0311 - acc: 0.9970 - val_loss: 0.2299 - val_acc: 0.9828
#
# Epoch 00059: val_acc did not improve from 0.98630
# Epoch 60/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0341 - acc: 0.9969 - val_loss: 0.2116 - val_acc: 0.9842
#
# Epoch 00060: val_acc did not improve from 0.98630
# Epoch 61/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0277 - acc: 0.9974 - val_loss: 0.2234 - val_acc: 0.9831
#
# Epoch 00061: val_acc did not improve from 0.98630
# Epoch 62/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0270 - acc: 0.9975 - val_loss: 0.1871 - val_acc: 0.9854
#
# Epoch 00062: val_acc did not improve from 0.98630
# Epoch 63/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0288 - acc: 0.9977 - val_loss: 0.2138 - val_acc: 0.9844
#
# Epoch 00063: val_acc did not improve from 0.98630
# Epoch 64/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0280 - acc: 0.9975 - val_loss: 0.2008 - val_acc: 0.9856
#
# Epoch 00064: val_acc did not improve from 0.98630
# Epoch 65/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0261 - acc: 0.9977 - val_loss: 0.2177 - val_acc: 0.9838
#
# Epoch 00065: val_acc did not improve from 0.98630
# Epoch 66/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0259 - acc: 0.9976 - val_loss: 0.1864 - val_acc: 0.9860
#
# Epoch 00066: val_acc did not improve from 0.98630
# Epoch 67/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0226 - acc: 0.9979 - val_loss: 0.2135 - val_acc: 0.9835
#
# Epoch 00067: val_acc did not improve from 0.98630
# Epoch 68/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0325 - acc: 0.9970 - val_loss: 0.2365 - val_acc: 0.9824
#
# Epoch 00068: val_acc did not improve from 0.98630
# Epoch 69/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0361 - acc: 0.9970 - val_loss: 0.2233 - val_acc: 0.9833
#
# Epoch 00069: val_acc did not improve from 0.98630
# Epoch 70/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0319 - acc: 0.9974 - val_loss: 0.2307 - val_acc: 0.9832
#
# Epoch 00070: val_acc did not improve from 0.98630
# Epoch 71/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0286 - acc: 0.9976 - val_loss: 0.2421 - val_acc: 0.9828
#
# Epoch 00071: val_acc did not improve from 0.98630
# Epoch 72/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0253 - acc: 0.9979 - val_loss: 0.2341 - val_acc: 0.9834
#
# Epoch 00072: val_acc did not improve from 0.98630
# Epoch 73/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0314 - acc: 0.9972 - val_loss: 0.2149 - val_acc: 0.9840
#
# Epoch 00073: val_acc did not improve from 0.98630
# Epoch 74/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0335 - acc: 0.9973 - val_loss: 0.2119 - val_acc: 0.9839
#
# Epoch 00074: val_acc did not improve from 0.98630
# Epoch 75/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0257 - acc: 0.9978 - val_loss: 0.2100 - val_acc: 0.9851
#
# Epoch 00075: val_acc did not improve from 0.98630
# Epoch 76/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0261 - acc: 0.9976 - val_loss: 0.2068 - val_acc: 0.9850
#
# Epoch 00076: val_acc did not improve from 0.98630
# Epoch 77/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0238 - acc: 0.9981 - val_loss: 0.1995 - val_acc: 0.9852
#
# Epoch 00077: val_acc did not improve from 0.98630
# Epoch 78/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0244 - acc: 0.9978 - val_loss: 0.2228 - val_acc: 0.9844
#
# Epoch 00078: val_acc did not improve from 0.98630
# Epoch 79/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0282 - acc: 0.9975 - val_loss: 0.2485 - val_acc: 0.9825
#
# Epoch 00079: val_acc did not improve from 0.98630
# Epoch 80/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0258 - acc: 0.9978 - val_loss: 0.2109 - val_acc: 0.9849
#
# Epoch 00080: val_acc did not improve from 0.98630
# Epoch 81/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0279 - acc: 0.9977 - val_loss: 0.2193 - val_acc: 0.9833
#
# Epoch 00081: val_acc did not improve from 0.98630
# Epoch 82/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0254 - acc: 0.9979 - val_loss: 0.2038 - val_acc: 0.9855
#
# Epoch 00082: val_acc did not improve from 0.98630
# Epoch 83/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0234 - acc: 0.9980 - val_loss: 0.2038 - val_acc: 0.9850
#
# Epoch 00083: val_acc did not improve from 0.98630
# Epoch 84/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0216 - acc: 0.9981 - val_loss: 0.2196 - val_acc: 0.9843
#
# Epoch 00084: val_acc did not improve from 0.98630
# Epoch 85/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0198 - acc: 0.9982 - val_loss: 0.2031 - val_acc: 0.9854
#
# Epoch 00085: val_acc did not improve from 0.98630
# Epoch 86/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0229 - acc: 0.9981 - val_loss: 0.1985 - val_acc: 0.9854
#
# Epoch 00086: val_acc did not improve from 0.98630
# Epoch 87/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0234 - acc: 0.9980 - val_loss: 0.2082 - val_acc: 0.9852
#
# Epoch 00087: val_acc did not improve from 0.98630
# Epoch 88/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0216 - acc: 0.9981 - val_loss: 0.2127 - val_acc: 0.9846
#
# Epoch 00088: val_acc did not improve from 0.98630
# Epoch 89/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0233 - acc: 0.9981 - val_loss: 0.1762 - val_acc: 0.9871
#
# Epoch 00089: val_acc improved from 0.98630 to 0.98710, saving model to /root/workspace/bnn_p4/BaNaNa-split-binarization/baselines/saved_models/MLP_mnist_model.089-0.99.h5
# Epoch 90/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 0.0210 - acc: 0.9983 - val_loss: 0.1961 - val_acc: 0.9858
#
# Epoch 00090: val_acc did not improve from 0.98710
# Epoch 91/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0219 - acc: 0.9981 - val_loss: 0.2100 - val_acc: 0.9853
#
# Epoch 00091: val_acc did not improve from 0.98710
# Epoch 92/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0241 - acc: 0.9980 - val_loss: 0.2498 - val_acc: 0.9819
#
# Epoch 00092: val_acc did not improve from 0.98710
# Epoch 93/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0183 - acc: 0.9984 - val_loss: 0.2336 - val_acc: 0.9829
#
# Epoch 00093: val_acc did not improve from 0.98710
# Epoch 94/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0220 - acc: 0.9981 - val_loss: 0.2170 - val_acc: 0.9845
#
# Epoch 00094: val_acc did not improve from 0.98710
# Epoch 95/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0218 - acc: 0.9981 - val_loss: 0.2090 - val_acc: 0.9851
#
# Epoch 00095: val_acc did not improve from 0.98710
# Epoch 96/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0204 - acc: 0.9984 - val_loss: 0.2223 - val_acc: 0.9843
#
# Epoch 00096: val_acc did not improve from 0.98710
# Epoch 97/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0227 - acc: 0.9981 - val_loss: 0.2383 - val_acc: 0.9834
#
# Epoch 00097: val_acc did not improve from 0.98710
# Epoch 98/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0196 - acc: 0.9983 - val_loss: 0.1965 - val_acc: 0.9864
#
# Epoch 00098: val_acc did not improve from 0.98710
# Epoch 99/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0223 - acc: 0.9982 - val_loss: 0.2058 - val_acc: 0.9853
#
# Epoch 00099: val_acc did not improve from 0.98710
# Epoch 100/100
# 60000/60000 [==============================] - 11s 179us/step - loss: 0.0206 - acc: 0.9983 - val_loss: 0.2177 - val_acc: 0.9850
#
# Epoch 00100: val_acc did not improve from 0.98710
